# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:34207' processes=4 threads=12, memory=7.66 GiB>

# %%
import dask.dataframe as dd

ddf = dd.read_csv(r'../../dataset/NF-BoT-IoT-v2/befb58edf3428167_MOHANAD_A4706/data/NF-BoT-IoT-v2.csv')
ddf
# Out:
# Dask DataFrame Structure:
#                IPV4_SRC_ADDR L4_SRC_PORT IPV4_DST_ADDR L4_DST_PORT PROTOCOL L7_PROTO IN_BYTES IN_PKTS OUT_BYTES OUT_PKTS TCP_FLAGS CLIENT_TCP_FLAGS SERVER_TCP_FLAGS FLOW_DURATION_MILLISECONDS DURATION_IN DURATION_OUT MIN_TTL MAX_TTL LONGEST_FLOW_PKT SHORTEST_FLOW_PKT MIN_IP_PKT_LEN MAX_IP_PKT_LEN SRC_TO_DST_SECOND_BYTES DST_TO_SRC_SECOND_BYTES RETRANSMITTED_IN_BYTES RETRANSMITTED_IN_PKTS RETRANSMITTED_OUT_BYTES RETRANSMITTED_OUT_PKTS SRC_TO_DST_AVG_THROUGHPUT DST_TO_SRC_AVG_THROUGHPUT NUM_PKTS_UP_TO_128_BYTES NUM_PKTS_128_TO_256_BYTES NUM_PKTS_256_TO_512_BYTES NUM_PKTS_512_TO_1024_BYTES NUM_PKTS_1024_TO_1514_BYTES TCP_WIN_MAX_IN TCP_WIN_MAX_OUT ICMP_TYPE ICMP_IPV4_TYPE DNS_QUERY_ID DNS_QUERY_TYPE DNS_TTL_ANSWER FTP_COMMAND_RET_CODE  Label  Attack
# npartitions=94
#                       object       int64        object       int64    int64  float64    int64   int64     int64    int64     int64            int64            int64                      int64       int64        int64   int64   int64            int64             int64          int64          int64                 float64                 float64                  int64                 int64                   int64                  int64                     int64                     int64                    int64                     int64                     int64                      int64                       int64          int64           int64     int64          int64        int64          int64          int64                int64  int64  object
#                          ...         ...           ...         ...      ...      ...      ...     ...       ...      ...       ...              ...              ...                        ...         ...          ...     ...     ...              ...               ...            ...            ...                     ...                     ...                    ...                   ...                     ...                    ...                       ...                       ...                      ...                       ...                       ...                        ...                         ...            ...             ...       ...            ...          ...            ...            ...                  ...    ...     ...
# ...                      ...         ...           ...         ...      ...      ...      ...     ...       ...      ...       ...              ...              ...                        ...         ...          ...     ...     ...              ...               ...            ...            ...                     ...                     ...                    ...                   ...                     ...                    ...                       ...                       ...                      ...                       ...                       ...                        ...                         ...            ...             ...       ...            ...          ...            ...            ...                  ...    ...     ...
#                          ...         ...           ...         ...      ...      ...      ...     ...       ...      ...       ...              ...              ...                        ...         ...          ...     ...     ...              ...               ...            ...            ...                     ...                     ...                    ...                   ...                     ...                    ...                       ...                       ...                      ...                       ...                       ...                        ...                         ...            ...             ...       ...            ...          ...            ...            ...                  ...    ...     ...
#                          ...         ...           ...         ...      ...      ...      ...     ...       ...      ...       ...              ...              ...                        ...         ...          ...     ...     ...              ...               ...            ...            ...                     ...                     ...                    ...                   ...                     ...                    ...                       ...                       ...                      ...                       ...                       ...                        ...                         ...            ...             ...       ...            ...          ...            ...            ...                  ...    ...     ...
# Dask Name: read-csv, 1 graph layer

# %%
ddf = ddf[(ddf['Attack'] == 'DDoS') | (ddf['Attack'] == 'Benign')]
ddf.Attack.value_counts().compute()
# Out:
# DDoS      18331847
# Benign      135037
# Name: Attack, dtype: int64

# %%
ddf = ddf.drop(['IPV4_SRC_ADDR', 'IPV4_DST_ADDR', 'L4_SRC_PORT', 'L4_DST_PORT', 'Label', 'MAX_TTL', 'MIN_TTL'], axis = 1)

# %%
X = ddf.loc[:, ddf.columns != 'Attack']
X.head()
# Out:
#     PROTOCOL  L7_PROTO  IN_BYTES  IN_PKTS  OUT_BYTES  OUT_PKTS  TCP_FLAGS  \
# 3         17     188.0        56        2          0         0          0
# 4         17     188.0        56        2          0         0          0
# 5         17     188.0        84        3          0         0          0
# 7         17     188.0        56        2          0         0          0
# 10        17     188.0        56        2          0         0          0
#
#     CLIENT_TCP_FLAGS  SERVER_TCP_FLAGS  FLOW_DURATION_MILLISECONDS  ...  \
# 3                  0                 0                     4294545  ...
# 4                  0                 0                     4293732  ...
# 5                  0                 0                     4293826  ...
# 7                  0                 0                     4294502  ...
# 10                 0                 0                     4293656  ...
#
#     NUM_PKTS_512_TO_1024_BYTES  NUM_PKTS_1024_TO_1514_BYTES  TCP_WIN_MAX_IN  \
# 3                            0                            0               0
# 4                            0                            0               0
# 5                            0                            0               0
# 7                            0                            0               0
# 10                           0                            0               0
#
#     TCP_WIN_MAX_OUT  ICMP_TYPE  ICMP_IPV4_TYPE  DNS_QUERY_ID  DNS_QUERY_TYPE  \
# 3                 0          0               0             0               0
# 4                 0          0               0             0               0
# 5                 0          0               0             0               0
# 7                 0          0               0             0               0
# 10                0          0               0             0               0
#
#     DNS_TTL_ANSWER  FTP_COMMAND_RET_CODE
# 3                0                     0
# 4                0                     0
# 5                0                     0
# 7                0                     0
# 10               0                     0
#
# [5 rows x 37 columns]

# %%
Y = ddf['Attack']
Y.head()
# Out:
# 3     DDoS
# 4     DDoS
# 5     DDoS
# 7     DDoS
# 10    DDoS
# Name: Attack, dtype: object

# %%
from dask_ml.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the string labels to integer classes
y_encoded = label_encoder.fit_transform(Y)

# # Print the mapping between original labels and encoded classes
# label_mapping = dict(zip(Y, y_encoded))
# print("Label Mapping:", label_mapping)

# # Reverse transform: Convert encoded classes back to original labels
# y_decoded = label_encoder.inverse_transform(y_encoded)
# print("Reverse Labels:", y_decoded)
# Out:
# 2023-11-16 14:52:44,821 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.40 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,015 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.40 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,124 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.35 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,455 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 1.60 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,516 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.43 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,550 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 1.60 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,719 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:37703 (pid=2176) exceeded 95% memory budget. Restarting...
# 2023-11-16 14:52:45,747 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 1.59 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,826 - distributed.nanny - WARNING - Restarting worker
# 2023-11-16 14:52:45,871 - distributed.worker.memory - WARNING - Worker is at 62% memory usage. Resuming worker. Process memory: 1.20 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:45,891 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 1.55 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:46,254 - distributed.worker.memory - WARNING - Worker is at 42% memory usage. Resuming worker. Process memory: 831.71 MiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:52:46,411 - distributed.worker.memory - WARNING - Worker is at 54% memory usage. Resuming worker. Process memory: 1.05 GiB -- Worker memory limit: 1.92 GiB

# %%
from dask_ml.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.35, convert_mixed_types=True)
# Out:
# 2023-11-16 14:54:01,917 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.37 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:54:11,923 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.42 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:54:12,018 - distributed.worker.memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 1.55 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:54:12,221 - distributed.worker.memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 1.51 GiB -- Worker memory limit: 1.92 GiB

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(verbose=1)

# %%
import joblib
with joblib.parallel_backend('dask'):
     model.fit(X_train, y_train)
     predictions = model.predict(X_test)
# Out:
# 2023-11-16 14:55:27,518 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.36 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:28,027 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 1.56 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:28,200 - distributed.worker.memory - WARNING - Worker is at 63% memory usage. Resuming worker. Process memory: 1.22 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:30,793 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.21 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:33,098 - distributed.worker.memory - WARNING - Worker is at 84% memory usage. Pausing worker.  Process memory: 1.61 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:33,346 - distributed.worker.memory - WARNING - Worker is at 44% memory usage. Resuming worker. Process memory: 868.95 MiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:41,400 - distributed.worker.memory - WARNING - Worker is at 82% memory usage. Pausing worker.  Process memory: 1.57 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:41,540 - distributed.worker.memory - WARNING - Worker is at 45% memory usage. Resuming worker. Process memory: 900.02 MiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:48,145 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 1.60 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:55:48,445 - distributed.worker.memory - WARNING - Worker is at 64% memory usage. Resuming worker. Process memory: 1.24 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:56:08,806 - distributed.worker.memory - WARNING - Worker is at 86% memory usage. Pausing worker.  Process memory: 1.67 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:56:09,003 - distributed.worker.memory - WARNING - Worker is at 68% memory usage. Resuming worker. Process memory: 1.31 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:57:49,612 - distributed.worker.memory - WARNING - gc.collect() took 1.395s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# 2023-11-16 14:57:49,614 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 1.56 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:57:49,768 - distributed.worker.memory - WARNING - Worker is at 49% memory usage. Resuming worker. Process memory: 0.94 GiB -- Worker memory limit: 1.92 GiB
# [Parallel(n_jobs=-1)]: Using backend DaskDistributedBackend with 12 concurrent workers.
# 2023-11-16 14:58:35,649 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 1.46 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:58:35,717 - distributed.worker.memory - WARNING - Worker is at 81% memory usage. Pausing worker.  Process memory: 1.55 GiB -- Worker memory limit: 1.92 GiB
# 2023-11-16 14:58:35,966 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:44857 (pid=2171) exceeded 95% memory budget. Restarting...
# 2023-11-16 14:58:35,998 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f0a78207880>>, <Task finished name='Task-203914' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py:327> exception=CommClosedError('in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed')>)
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 305, in maybe_to_futures
#     f = await t
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/client.py", line 2456, in _scatter
#     await self.scheduler.scatter(
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1359, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1118, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed
# 2023-11-16 14:58:36,003 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f0a78207880>>, <Task finished name='Task-203915' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py:327> exception=CommClosedError('in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed')>)
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 305, in maybe_to_futures
#     f = await t
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/client.py", line 2456, in _scatter
#     await self.scheduler.scatter(
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1359, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1118, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed
# 2023-11-16 14:58:36,004 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f0a78207880>>, <Task finished name='Task-203916' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py:327> exception=CommClosedError('in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed')>)
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 305, in maybe_to_futures
#     f = await t
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/client.py", line 2456, in _scatter
#     await self.scheduler.scatter(
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1359, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1118, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed
# 2023-11-16 14:58:36,006 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7f0a78207880>>, <Task finished name='Task-203917' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py:327> exception=CommClosedError('in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed')>)
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
# ...
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 740, in _run_callback
#     ret = callback()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/tornado/ioloop.py", line 764, in _discard_future_result
#     future.result()
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 279, in maybe_to_futures
#     f = await call_data_futures[arg]
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 328, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 315, in _to_func_args
#     args = list(await maybe_to_futures(args))
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/joblib/_dask.py", line 305, in maybe_to_futures
#     f = await t
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/client.py", line 2456, in _scatter
#     await self.scheduler.scatter(
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1359, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/core.py", line 1118, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/home/shaanzie/.local/lib/python3.8/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.scatter local=tcp://127.0.0.1:42138 remote=tcp://127.0.0.1:34207>: Stream is closed
# 2023-11-16 14:58:36,050 - distributed.nanny - WARNING - Restarting worker

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'y_true' is your true labels and 'y_pred' is your predicted labels
conf_matrix = confusion_matrix(y_test, predictions)

# Display the confusion matrix using a heatmap
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np

# Get feature importances from the trained model
feature_importances = model.feature_importances_

# Get the indices of features sorted by importance
sorted_indices = np.argsort(feature_importances)[::-1]

# Get the names of the features
feature_names = X.columns

# Print the importance of each feature
for i, idx in enumerate(sorted_indices):
    print(f"{i + 1}. {feature_names[idx]}: {feature_importances[idx]}")

# Plotting the feature importances
plt.bar(range(len(feature_importances)), feature_importances[sorted_indices])
plt.xticks(range(len(feature_importances)), np.array(feature_names)[sorted_indices], rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Random Forest Classifier - Feature Importance')
plt.show()
